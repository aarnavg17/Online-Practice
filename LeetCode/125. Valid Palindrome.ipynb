# %%
#Your runtime beats 97.14 % of python3 submissions
#Your memory usage beats 60.41 % of python3 submissions.
class Solution:
    def isPalindrome(self, s: str) -> bool:
        s = s.lower()
        a = ""
        for x in s:
            if x.isalnum():
                a = a + x
        if a == a[::-1]:
            return True
        else:
            return False

# %%
s = "OP"
s = s.lower()
a = ""
for x in s:
    if x.isalphanum():
        a = a + x
if a == a[::-1]:
    print (True)
else:
    print (False)
# Out:
# False
