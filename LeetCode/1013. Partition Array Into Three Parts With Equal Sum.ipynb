# %%
#Runtime: 360 ms, faster than 29.82% of Python3 online submissions
#Memory Usage: 20.4 MB, less than 79.92% of Python3 online submissions
class Solution:
    def canThreePartsEqualSum(self, A: List[int]) -> bool:
        sum_total=sum(A)
        if sum_total%3!=0:
            return False
        sum_needed=sum_total/3
        sum1,sum2,i,j=0,0,0,-1
        length=len(A)
        for num in A:
            j+=1
            sum1+=num
            if sum1==sum_needed:
                i+=1
                sum1=0
            if i==3:
                if num!=A[length-1]:
                    for x in range (j+1,length):
                        sum2+=A[x]
                    if sum2!=0:
                        return False
                    else:
                        return True
                else:
                    return True
