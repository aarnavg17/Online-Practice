# %%
n=int(input())
bin=[]
while n:
    bin.insert(0,n%2)
    n//=2
count=0
count_max=0
for i in bin:
    if i==1:
        count+=1
        if count>count_max:
            count_max=count
    else:
        count=0
print (count_max)
# Out:
# 13
# 2
