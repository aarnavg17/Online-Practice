# %%
n=int(input())
phoneBook=dict(input().split() for _ in range(n))
while True:
    try:
        search=input()
        try:
            print(search,'=',phoneBook[search],sep='')
        except:
            print('Not found')
    except:
        break
