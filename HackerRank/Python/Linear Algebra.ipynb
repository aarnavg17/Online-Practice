# %%
A = [input().split() for _ in range(2)]
print(A)
# Out:
# 5 4 1
# 9 7 6
# ([['5', '4', '1'], ['9', '7', '6']], <class 'int'>)

# %%
import numpy as np
A = np.array([input().split() for _ in range(int(input()))], float)
print(round(np.linalg.det(A), 2))
