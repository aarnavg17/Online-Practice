# %%
import time
start=time.time()
import math
tri_num=0
i=0
num_div=0
while num_div<500:
  i+=1
  tri_num+=i
  num_div=2
  for div in range (2,math.floor(tri_num**0.5)+1):
    if tri_num%div==0:
      num_div+=2
print(tri_num)
print(time.time()-start)
# Out:
# 76576500
# 6.652154445648193
