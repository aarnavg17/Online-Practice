# %%
import time
start=time.time()
import math
print(math.factorial(40)/(math.factorial(20)*math.factorial(20)))

#Aadhe time neeche aayega aadhe time right. 2n total chalna padega. 2nCn se choose karlo kitne alag alag time pe right aana hai.
# Out:
# 137846528820.0
