# %%
import math
import time
start=time.time()
fact=str(math.factorial(100))
sum_digit=0
for digit in fact:
  sum_digit+=int(digit)
print(sum_digit)
print(time.time()-start)
# Out:
# 648
# 0.00036144256591796875
