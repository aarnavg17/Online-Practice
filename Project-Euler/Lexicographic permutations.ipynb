# %%
import time
start=time.time()
def digit(number):
  a=[]
  if number<1000000000:
    while number:
      if number%10 in a or number%10==0:
        break
      else:
        a.append(number%10)
        number//=10
    if len(a)==9:
      return True
    else:
      return False
  else:
    while number:
      if number%10 in a:
        break
      else:
        a.append(number%10)
        number//=10
    if len(a)==10:
      return True
    else:
      return False
i=0
num=123456788
while i!=1000000:
  num+=1
  if digit(num):
    i+=1
print (num)
print(time.time()-start)
# Out:
# 2783915460
# 2767.3637268543243

# %%
import time
start=time.time()
def digit(number):
  if number<1000000000:
    a=[int()+1]*9
    while number:
      a[(number%10)-1]-=1
      number//=10
    if any(a):
      return False
    else:
      return True
  else:
    a=[int()+1]*10
    while number:
      a[(number%10)]-=1
      number//=10
    if any(a):
      return False
    else:
      return True
i=0
num=123456788
while i!=1000000:
  num+=1
  if digit(num):
    i+=1
    #print(i)
    #print(num)
print (num)
print(time.time()-start)

# %%
a=[1,-1,0]
if any(a):
  print("x")
else:
  print(a)
# Out:
# x
