# %%
import time
start=time.time()
number=...
large_product=1
num_list=list(map(int,str(number)))
for i in range (0,len(num_list)-12):
  current_product=1
  for j in range (i,i+13):
    current_product*=num_list[j]
  if current_product>large_product:
    large_product=current_product
print(large_product)
print(time.time()-start)
# Out:
# 23514624000
# 0.0024378299713134766
