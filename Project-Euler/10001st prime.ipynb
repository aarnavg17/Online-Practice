# %%
import time
start=time.time()
import math
nth_prime=4
i=9
flag=False
while nth_prime<10001:
  i+=2
  for j in range (3,math.ceil(i**0.5)+1,2):
    if i%j:
      flag=True
    else:
      flag=False
      break
  if flag:
    nth_prime+=1
    flag=False
print (i)
print(time.time()-start)
# Out:
# 104743
# 0.19022440910339355
