# %%
import time
start=time.time()
i=0
check=True
while check==True:
  i+=2520
  for j in range (19, 10, -1):
    if i%j!=0:
      break
    if j==11:
      check=False
      print (i)
print(time.time()-start)
# Out:
# 232792560
# 0.050011634826660156
