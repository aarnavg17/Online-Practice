# %%
import time
start=time.time()
fib=[1,1,2]
index=2
i,j=0,1
i=3
while len(str(fib[2]))<1000:
  index+=1
  fib[2]=fib[1]+fib[0]
  fib[0]=fib[1]
  fib[1]=fib[2]
print(index)
print(time.time()-start)
# Out:
# 4782
# 0.034905433654785156
