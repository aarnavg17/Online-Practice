# %%
T=int(input())
for i in range (0,T):
    N=int(input())
    sum=(3*((N-1)//3)*(((N-1)//3)+1)//2)+(5*((N-1)//5)*(((N-1)//5)+1)//2)-(15*((N-1)//15)*(((N-1)//15)+1)//2)
    print(sum)

# %%
T=int(input())
for i in range (0,T):
    N=int(input())
    sum=0
    for j in range (1,N):
        if j%3==0 or j%5==0:
            sum+=j
    print(sum)
