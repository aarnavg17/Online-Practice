# %%
import time
start=time.time()
sum_of_square=int()
sum=int()
for i in range (1,101):
  sum_of_square+=(i**2)
  sum+=i
print((sum**2)-sum_of_square)
print(time.time()-start)
# Out:
# 25164150
# 0.0005414485931396484
